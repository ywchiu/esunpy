# %% [markdown]
# ### 問題一 (5%)
#
# 複利終值 : 複利終值指一定量的貨幣，按複利計算的若干期後的本利總和。
#
#
# 公式如下：
# \\( S = p(1 + i)^n \\)
#
# - S為本利和
# - p為本金
# - i為利率
# - n為期數
#
# 請問如果有一筆錢(本金)100,000，存銀行定存，年利率3%(利率)，到了3年(期數)後會有多少錢(本利和)?
#
# **請使用Python 計算並列出計算過程**

# %% [markdown]
# ### 問題二 (10%)
#
# 現在在系統上看到客戶存入 'US$600,000' 的字串資訊，現在需要根據美金對新台幣的匯率(現金)29.325將該金額轉換成數字後存入系統，請使用Python 將該字串轉換為數字後，接著根據匯率轉換成台幣金額
#
# **請使用Python計算並列出計算過程**

# %%
s = 'US$600,000'

# %% [markdown]
# ### 問題三 (10%)
#
# 有一個公司這五年的年營收為
#
# - 第一年：10000000
# - 第二年：12000000
# - 第三年：11500000
# - 第四年：15000000
# - 第五年：16000000
#
# 請使用Python 計算這家公司這五年的平均營收(營收總和/年數)?
#
# **請使用Python計算並列出計算過程**

# %%
revenue = [10000000,12000000,11500000,15000000,16000000]

# %% [markdown]
# ### 問題四 (10%)
#
# 交叉匯率指的是三個以上的貨幣，其中任何兩個貨幣的兌換匯率可用兩者與第三貨幣的匯率計算，此匯率稱為交叉匯率(cross rate)。
#
# 例：東京的日圓與美元間的匯率為￥101.84 / \\$，而紐約的台幣與美元間的匯率為 NT 27.10 / \\$，則透過美元計算的台幣與日圓間的交叉匯率為：  NT 0.2669/￥
#
# 三角套利指的是當交叉匯率不等於市場匯率時，同時在三個市場上買賣三種貨幣使之相等。
#
# 請問假設有10,000美元兌換成台幣，然後將台幣兌換為日圓，再將日圓兌換成美元，請問最後兌換到的價值有多少美金?
#
# **請使用Python Dictionary計算並列出計算過程**

# %%
exchange_rate = {
   'JPY/USD': 101.84,
   'NTD/USD': 27.1,
   'NTD/JPY': 0.2669
}

# %% [markdown]
# ### 問題五 (10%)
#
# 現有三家分行承作換匯、繳費、存款、開戶等業務，我們現將這三家一天的營業內容存成於一字典之中，並將這三家當天承作的業務以Tuple 的形式擺放到對應銀行的對應值中，請使用Python 計算三家銀行在一天的總開戶數有多少?
#
# **請使用Python計算並列出計算過程**

# %%
bank_dic = {
    'A': ('繳費', '開戶', '開戶', '開戶', '開戶', '開戶', '開戶', '換匯', '繳費', '繳費'),
    'B': ('繳費', '換匯', '換匯', '換匯', '繳費', '開戶', '繳費', '開戶'),
    'C': ('繳費', '開戶', '存款', '繳費', '繳費', '繳費', '開戶', '繳費', '換匯', '存款', '繳費', '存款')
}

# %% [markdown]
# ### 問題六 (10%)
#
# 現有三個業務，他們各自將他們拜訪的企業客戶名單記錄於一Python List 之中
#
# ````
# sales1 = ['C594', 'C449', 'C887', 'C126', 'C468', 'C258', 'C221', 'C505', 'C714']
# sales2 = ['C313', 'C714', 'C286', 'C432', 'C666', 'C356', 'C855', 'C476', 'C126', 'C643', 'C926']
# sales3 = ['C193', 'C941', 'C126', 'C590', 'C414', 'C065', 'C714']
# ````
#
# 請使用Python 找出有哪些客戶名單是這三個業務共同開發過的?
#
# **請使用Python計算並列出計算過程**

# %%
sales1 = ['C594', 'C449', 'C887', 'C126', 'C468', 'C258', 'C221', 'C505', 'C714']
sales2 = ['C313', 'C714', 'C286', 'C432', 'C666', 'C356', 'C855', 'C476', 'C126', 'C643', 'C926']
sales3 = ['C193', 'C941', 'C126', 'C590', 'C414', 'C065', 'C714']

# %% [markdown]
# ### 問題七 (10%)
#
# 有一業務今天撥打了數通電話開發新客源，但撥打的電話中有包含市話與手機號碼(09XXXXXXXX)，請使用Python 統計出今天該業務一共撥打了幾通手機號碼出去?
#
# ````
# phonecall = ['0914514126', '0993623819', '0992850648', '0954365410', '03-6949000', '0985512914', '0935770139', '0912852813', '0944987869', '0980685204', '03-5542615', '02-6338673', '02-1076622', '02-6832691', '0951859556', '03-3574856', '02-6531810', '0911563100', '03-3489073', '0902918795', '02-3517886', '03-1668413', '0902197860', '0924682908', '02-6027277', '02-1363389', '03-0842909', '02-0843773', '0971153647', '0919904753', '03-2139859', '0961695665', '02-7073674', '0954628414', '02-4627660', '03-1410712', '03-3826513', '02-2998016', '02-7993017', '0911607501', '03-7912519', '0914875480', '0916711466', '0919436315', '02-7777202', '03-9676001', '0942708276', '02-2793450', '0991317284', '0978271573', '03-8860927', '02-7575368', '02-0799818']
# ````
#
# **請使用Python計算並列出計算過程**

# %%
phonecall = ['0914514126', '0993623819', '0992850648', '0954365410', '03-6949000', '0985512914', '0935770139', '0912852813', '0944987869', '0980685204', '03-5542615', '02-6338673', '02-1076622', '02-6832691', '0951859556', '03-3574856', '02-6531810', '0911563100', '03-3489073', '0902918795', '02-3517886', '03-1668413', '0902197860', '0924682908', '02-6027277', '02-1363389', '03-0842909', '02-0843773', '0971153647', '0919904753', '03-2139859', '0961695665', '02-7073674', '0954628414', '02-4627660', '03-1410712', '03-3826513', '02-2998016', '02-7993017', '0911607501', '03-7912519', '0914875480', '0916711466', '0919436315', '02-7777202', '03-9676001', '0942708276', '02-2793450', '0991317284', '0978271573', '03-8860927', '02-7575368', '02-0799818']

# %% [markdown]
# ### 問題八(10%)
#
# 請撰寫一個名為convertMoney的函式，能將使用者輸入的數字，回傳增加千位符號後的字串，但若使用者輸入的若非數字，系統則會回傳None。
#
# 例如：
#
# 使用者輸入 123000 函數回傳 123,000
# 使用者輸入 hello  函數則回傳 None
#
#
# **請使用Python計算並列出計算過程**

# %% [markdown]
# ### 問題九(15%)
#
# 現有一個對話機器人的類別 Robot，內建一些使用者對話庫，可以根據使用者的輸入，產生一些對話內容。
#
# ```
# class Robot(object):
#     def __init__(self, name):
#         self.qa = {
#             '貸款': '以下是貸款部門的專線',
#             '理財': '以下是理財部門的專線'
#         }
#         self.name = name
#
#     def add_qa(self, qa):
#         self.qa.update(qa)
#
#     def get_qa(self, question):
#         return self.qa(question, '我現在還不聰明，等我變聰明以後再告訴你')
#
# ```
#
# 請在不修改類別的情況下
#
# 1. 利用該類別建立一名為(name = 'esun')機器人物件?
# 2. 為機器人的對話庫增加以下問答{'早安': '你也早安'}?
# 3. 當使用者輸入「早安」時，取得機器人的回答？
#
#
# **請使用Python計算並列出計算過程**

# %%
class Robot(object):
    def __init__(self, name):
        self.qa = {
            '貸款': '以下是貸款部門的專線',
            '理財': '以下是理財部門的專線'
        } 
        self.name = name
    
    def add_qa(self, qa):
        self.qa.update(qa)
    
    def get_qa(self, question):
        return self.qa.get(question, '我現在還不聰明，等我變聰明以後再告訴你')

# %% [markdown]
# ### 問題十 (10%)
#
# 現有一資料集 Churn_Modelling.csv (https://github.com/ywchiu/esunpy/blob/master/data/Churn_Modelling.csv) ，描述客戶的基本資料與客戶是否流失(Churn) 等基本資訊，請讀入該資料集後，計算各性別(Gender)的平均預估薪資(EstimatedSalary)？
#
#
#
# **附註**
#
# 在colab 可以使用以下指令下載檔案
# ````
# ! wget https://raw.githubusercontent.com/ywchiu/esunpy/master/data/Churn_Modelling.csv
# ````
#
#
#
# 可以使用純python 進行讀檔並計算，也可以使用pandas 等套件進行計算
#
#
# **請使用Python計算並列出計算過程**
